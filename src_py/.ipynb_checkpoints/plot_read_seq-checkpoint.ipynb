# %%
import os 
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
PATH = "../src/data_read_seq"
EXT = "*.csv"

# %%
all_csv_files = [file
                 for path, subdir, files in os.walk(PATH)
                 for file in glob(os.path.join(path, EXT))]

# %%
all_csv_files
# Out:
# ['../src/data_read_seq/trace_read4B.csv',
#  '../src/data_read_seq/trace_read1B.csv',
#  '../src/data_read_seq/trace_read16B.csv',
#  '../src/data_read_seq/trace_read8B.csv',
#  '../src/data_read_seq/trace_read64B.csv',
#  '../src/data_read_seq/trace_read32B.csv']

# %%
pd.options.display.float_format = '{:.6f}'.format
df_read = [pd.read_csv(file, delimiter=" ") for file in all_csv_files]

# %%
df_read[0].head()
# Out:
#               temps  type  taille  latence
# 0 1597073154.869347  read       4 0.000018
# 1 1597073154.869406  read       4 0.000015
# 2 1597073154.869452  read       4 0.000014
# 3 1597073154.869495  read       4 0.000014
# 4 1597073154.869538  read       4 0.000014

# %%
df_read[0].columns
# Out:
# Index(['temps', 'type', 'taille', 'latence'], dtype='object')

# %%
#données des lectures aléatoires de 4 bytes
begin_time_seq4 = df_read[0]["temps"][0]
x_seq4 = df_read[0]["temps"] - begin_time_seq4
y_seq4 = df_read[0]["latence"]
y_seq4.head()
# Out:
# 0   0.000018
# 1   0.000015
# 2   0.000014
# 3   0.000014
# 4   0.000014
# Name: latence, dtype: float64

# %%
#plot données des lectures sequentielles
plt.figure(figsize=(12, 3))
plt.plot(x_seq4, y_seq4, "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture sequentielle de 4 bytes')
plt.savefig("../outplot/read/seq/read_seq4.png")
plt.show()

# %%
#données des lectures aléatoires de 1 bytes
begin_time_seq1 = df_read[1]["temps"][0]
x_seq1 = df_read[1]["temps"] - begin_time_seq1
y_seq1 = df_read[1]["latence"]
y_seq1.head()
# Out:
# 0   0.000011
# 1   0.000016
# 2   0.000009
# 3   0.000009
# 4   0.000008
# Name: latence, dtype: float64

# %%
#plot données des lectures sequentielles 1 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq1, y_seq1, "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture sequentielle de 1 bytes')
plt.savefig("../outplot/read/seq/read_seq1.png")
plt.show()

# %%
#données des lectures aléatoires de 16 bytes
begin_time_seq16 = df_read[2]["temps"][0]
x_seq16 = df_read[2]["temps"] - begin_time_seq16
y_seq16 = df_read[2]["latence"]
y_seq16.head()
# Out:
# 0   0.000028
# 1   0.000022
# 2   0.000021
# 3   0.000020
# 4   0.000020
# Name: latence, dtype: float64

# %%
#plot données des lectures sequentielles 16 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq16, y_seq16, "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture sequentielle de 1 bytes')
plt.savefig("../outplot/read/seq/read_seq16.png")
plt.show()

# %%
#données des lectures aléatoires de 8 bytes
begin_time_seq8 = df_read[3]["temps"][0]
x_seq8 = df_read[3]["temps"] - begin_time_seq8
y_seq8 = df_read[3]["latence"]
y_seq8.head()
# Out:
# 0   0.000021
# 1   0.000016
# 2   0.000016
# 3   0.000015
# 4   0.000014
# Name: latence, dtype: float64

# %%
time_start = df["time"][0]
x = (df["time"] - df["time"] [0])*0.001
y = df["value"]*1e-9
plt.figure(figsize=(12, 3))
plt.plot(x[0:400] , y[0:400], "-o",linewidth =2.5)
