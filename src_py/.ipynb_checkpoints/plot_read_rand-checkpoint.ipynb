# %%
import os 
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
PATH = "../src/data_read_rand"
EXT = "*.csv"

# %%
all_csv_files = [file
                 for path, subdir, files in os.walk(PATH)
                 for file in glob(os.path.join(path, EXT))]

# %%
all_csv_files
# Out:
# ['../src/data_read_rand/trace_rread64B.csv',
#  '../src/data_read_rand/trace_rread8B.csv',
#  '../src/data_read_rand/trace_rread4B.csv',
#  '../src/data_read_rand/trace_rread16B.csv',
#  '../src/data_read_rand/trace_rread1B.csv',
#  '../src/data_read_rand/trace_rread32B.csv']

# %%
pd.options.display.float_format = '{:.6f}'.format
df_read = [pd.read_csv(file, delimiter=" ") for file in all_csv_files]

# %%
df_read[0].head()
# Out:
#               temps  type  taille  latence
# 0 1597076074.666241  read      64 0.000011
# 1 1597076074.666335  read      64 0.000014
# 2 1597076074.666454  read      64 0.000013
# 3 1597076074.666525  read      64 0.000009
# 4 1597076074.666586  read      64 0.000009

# %%
df_read[0].columns
# Out:
# Index(['temps', 'type', 'taille', 'latence'], dtype='object')

# %%
#données des lectures aléatoires
begin_time_rand64 = df_read[0]["temps"][0]
x_rand64 = df_read[0]["temps"] - begin_time_rand64
y_rand64 = df_read[0]["latence"]
y_rand64.head()
# Out:
# 0   0.000011
# 1   0.000014
# 2   0.000013
# 3   0.000009
# 4   0.000009
# Name: latence, dtype: float64

# %%
#plot données des lectures aléatoire
plt.figure(figsize=(12, 3))
plt.plot(x_rand64, y_rand64, "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture aléatoire de 64 bytes')
plt.savefig("../outplot/read/rand/read_rand64.png")
plt.show()

# %%
#données des lectures aléatoires de 8 bytes
begin_time_rand8 = df_read[1]["temps"][0]
x_rand8 = df_read[1]["temps"] - begin_time_rand8
y_rand8 = df_read[1]["latence"]
y_rand8.head()
# Out:
# 0   0.000015
# 1   0.000010
# 2   0.000012
# 3   0.000010
# 4   0.000010
# Name: latence, dtype: float64

# %%
#plot données des lectures sequentielles
plt.figure(figsize=(12, 3))
plt.plot(x_rand8, y_rand8, "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture aléatoire de 8 bytes')
plt.savefig("../outplot/read/rand/read_rand8.png")
plt.show()

# %%
#données des lectures aléatoires de 4 bytes
begin_time_rand4 = df_read[2]["temps"][0]
x_rand4 = df_read[2]["temps"] - begin_time_rand4
y_rand4 = df_read[2]["latence"]
y_rand4.head()
# Out:
# 0   0.000021
# 1   0.000015
# 2   0.000017
# 3   0.000013
# 4   0.000016
# Name: latence, dtype: float64

# %%
#plot données des lectures sequentielles
plt.figure(figsize=(12, 3))
plt.plot(x_rand4, y_rand4, "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture aléatoire de 4 bytes')
plt.savefig("../outplot/read/rand/read_rand4.png")
plt.show()

# %%
#données des lectures aléatoires de 16 bytes
begin_time_rand16 = df_read[3]["temps"][0]
x_rand16 = df_read[3]["temps"] - begin_time_rand16
y_rand16 = df_read[3]["latence"]
y_rand16.head()
# Out:
# 0   0.000025
# 1   0.000018
# 2   0.000174
# 3   0.000018
# 4   0.000012
# Name: latence, dtype: float64

# %%
#plot données des lectures sequentielles
plt.figure(figsize=(12, 3))
plt.plot(x_rand16, y_rand16, "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture aléatoire de 16 bytes')
plt.savefig("../outplot/read/rand/read_rand16.png")
plt.show()

# %%
#données des lectures aléatoires de 1 bytes
begin_time_rand1 = df_read[4]["temps"][0]
x_rand1 = df_read[4]["temps"] - begin_time_rand1
y_rand1 = df_read[4]["latence"]
y_rand1.head()
# Out:
# 0   0.000013
# 1   0.000008
# 2   0.000007
# 3   0.000007
# 4   0.000006
# Name: latence, dtype: float64

# %%
#plot données des lectures sequentielles
plt.figure(figsize=(12, 3))
plt.plot(x_rand1, y_rand1, "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture aléatoire de 1 bytes')
plt.savefig("../outplot/read/rand/read_rand1.png")
plt.show()

# %%
#données des lectures aléatoires de 32 bytes
begin_time_rand1 = df_read[4]["temps"][0]
x_rand1 = df_read[4]["temps"] - begin_time_rand1
y_rand1 = df_read[4]["latence"]
y_rand1.head()
