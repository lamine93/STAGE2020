# %%
import os 
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
PATH = "../src/data_write64B.step"
EXT = "*.csv"

# %%
#load data
all_csv_files = [file
                 for path, subdir, files in os.walk(PATH)
                 for file in glob(os.path.join(path, EXT))]

# %%
all_csv_files
# Out:
# ['../src/data_write64B.step/trace_write64B.step4.csv',
#  '../src/data_write64B.step/trace_write64B.step32.csv',
#  '../src/data_write64B.step/trace_write64B.step16.csv',
#  '../src/data_write64B.step/trace_write64B.step64.csv']

# %%
#read csv data 
pd.options.display.float_format = '{:.6f}'.format
df_write = [pd.read_csv(file, delimiter=" ") for file in all_csv_files]

# %%
df_write[1].head()
# Out:
#               temps   type  taille  latence
# 0 1597693074.687093  write      64 0.001125
# 1 1597693074.688533  write      64 0.000439
# 2 1597693074.689109  write      64 0.000392
# 3 1597693074.689602  write      64 0.000375
# 4 1597693074.690062  write      64 0.000851

# %%
df_write[0].columns
# Out:
# Index(['temps', 'type', 'taille', 'latence'], dtype='object')

# %%
#données des ecritures sequentielles par un pas de 4 bytes
begin_time_seq4 = df_write[0]["temps"][0]
x_seq4 = df_write[0]["temps"] - begin_time_seq4
y_seq4 = df_write[0]["latence"]
y_seq4.head()
# Out:
# 0   0.001278
# 1   0.000996
# 2   0.001390
# 3   0.004798
# 4   0.000759
# Name: latence, dtype: float64

# %%
#plot des données des écritures sequentielles par un pas de 4 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq4[:500], y_seq4[:500], "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('écriture de 64 Bytes par un pas de 4 Bytes')
plt.savefig("../outplot/write64B/write_step4.png")
plt.show()

# %%
#données des écritures sequentielles par un pas de 16 bytes
begin_time_seq16 = df_write[2]["temps"][0]
x_seq16 = df_write[2]["temps"] - begin_time_seq16
y_seq16 = df_write[2]["latence"]
y_seq16.head()
# Out:
# 0   0.001385
# 1   0.001078
# 2   0.000377
# 3   0.002414
# 4   0.000878
# Name: latence, dtype: float64

# %%
#plot des données des écritures sequentielles par un pas de 16 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq16[:500], y_seq16[:500], "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('écriture sequentielle de 64 Bytes par un pas de 16 Bytes')
plt.savefig("../outplot/write64B/write_step16.png")
plt.show()

# %%
#données des écritures sequentielles par un pas de 32 bytes
begin_time_seq32 = df_write[1]["temps"][0]
x_seq32 = df_write[1]["temps"] - begin_time_seq32
y_seq32 = df_write[1]["latence"]
y_seq32.head()
# Out:
# 0   0.001125
# 1   0.000439
# 2   0.000392
# 3   0.000375
# 4   0.000851
# Name: latence, dtype: float64

# %%
#plot des données des écritures sequentielles par un pas de 32 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq32[:500], y_seq32[:500], "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('écriture sequentielle de 64 Bytes par un pas de 32 Bytes')
plt.savefig("../outplot/write64B/write_step32.png")
plt.show()

# %%
#données des écritures sequentielles par un pas de 64 bytes
begin_time_seq64 = df_write[3]["temps"][0]
x_seq64 = df_write[3]["temps"] - begin_time_seq64
y_seq64 = df_write[3]["latence"]
y_seq64.head()
# Out:
# 0   0.004029
# 1   0.000872
# 2   0.000416
# 3   0.000426
# 4   0.000398
# Name: latence, dtype: float64

# %%
#plot des données des écritures sequentielles par un pas de 64 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq64[:500], y_seq64[:500], "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('écriture sequentielle de 64 Bytes par un pas de 64 Bytes')
plt.savefig("../outplot/write64B/write_step64.png")
plt.show()
