# %%
import os 
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
PATH = "../src/data_read16B.step"
EXT = "*.csv"

# %%
#load data
all_csv_files = [file
                 for path, subdir, files in os.walk(PATH)
                 for file in glob(os.path.join(path, EXT))]

# %%
all_csv_files
# Out:
# ['../src/data_read16B.step/trace_read16B.step32.csv',
#  '../src/data_read16B.step/trace_read16B.step16.csv',
#  '../src/data_read16B.step/trace_read16B.step64.csv',
#  '../src/data_read16B.step/trace_read16B.step4.csv']

# %%
#read csv data 
pd.options.display.float_format = '{:.6f}'.format
df_read = [pd.read_csv(file, delimiter=" ") for file in all_csv_files]

# %%
df_read[2].head()
# Out:
#               temps  type  taille  latence
# 0 1597685791.299708  read      16 0.000014
# 1 1597685791.299815  read      16 0.000008
# 2 1597685791.299870  read      16 0.000008
# 3 1597685791.299922  read      16 0.000008
# 4 1597685791.299975  read      16 0.000008

# %%
df_read[0].columns
# Out:
# Index(['temps', 'type', 'taille', 'latence'], dtype='object')

# %%
#données des lectures seq par un pas de 4 bytes
begin_time_seq4 = df_read[3]["temps"][0]
x_seq4 = df_read[3]["temps"] - begin_time_seq4
y_seq4 = df_read[3]["latence"]
y_seq4.tail()
# Out:
# 49995   0.000013
# 49996   0.000016
# 49997   0.000013
# 49998   0.000014
# 49999   0.000013
# Name: latence, dtype: float64

# %%
#plot des données des lectures seq par un pas de 4 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq4[:500], y_seq4[:500], "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture de 16 Bytes par un pas de 4 Bytes')
plt.savefig("../outplot/read16B/read_step4.png")
plt.show()

# %%
#données des lectures seq par un pas de 16 bytes
begin_time_seq16 = df_read[1]["temps"][0]
x_seq16 = df_read[1]["temps"] - begin_time_seq16
y_seq16 = df_read[1]["latence"]
y_seq16.head()
# Out:
# 0   0.000028
# 1   0.000022
# 2   0.000020
# 3   0.000018
# 4   0.000026
# Name: latence, dtype: float64

# %%
#plot des données des lectures seq par un pas de 16 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq16[:500], y_seq16[:500], "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture de 16 Bytes par un pas de 16 Bytes')
plt.savefig("../outplot/read16B/read_step16.png")
plt.show()

# %%
#données des lectures seq par un pas de 32 bytes
begin_time_seq32 = df_read[0]["temps"][0]
x_seq32 = df_read[0]["temps"] - begin_time_seq32
y_seq32 = df_read[0]["latence"]
y_seq32.head()
# Out:
# 0   0.000018
# 1   0.000016
# 2   0.000012
# 3   0.000012
# 4   0.000011
# Name: latence, dtype: float64

# %%
#plot des données des lectures seq par un pas de 32 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq32[:500], y_seq32[:500], "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture de 16 Bytes par un pas de 32 Bytes')
plt.savefig("../outplot/read16B/read_step32.png")
plt.show()

# %%
#données des lectures aléatoires par un pas de 64 bytes
begin_time_seq64 = df_read[2]["temps"][0]
x_seq64 = df_read[2]["temps"] - begin_time_seq64
y_seq64 = df_read[2]["latence"]
y_seq64.head()
# Out:
# 0   0.000014
# 1   0.000008
# 2   0.000008
# 3   0.000008
# 4   0.000008
# Name: latence, dtype: float64

# %%
#plot des données des lectures seq par un pas de 64 bytes
plt.figure(figsize=(12, 3))
plt.plot(x_seq64[:500], y_seq64[:500], "-o",linewidth =2.5)
plt.xlabel("date d'arrivée(s)")
plt.ylabel("latence(s)")
plt.title('lecture de 16 Bytes par un pas de 64 Bytes')
plt.savefig("../outplot/read16B/read_step64.png")
plt.show()
